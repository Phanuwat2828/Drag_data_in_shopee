# %%
import pandas as pd
import json
import os
# ระบุตำแหน่งของไดเร็กทอรีที่มีไฟล์ Excel
path = './Data_shopee';
# ตรวจสอบไฟล์ Excel ในโฟลเดอร์


file = '/shopee.xlsx';
header = ['col-xs-2-4 href', 'Fd4QmV src', 'FTxtVW',
       'customized-overlay-image src', 'DgXDzJ', 'bPcAVl', 'k9JZlv',
       'bx++ig 2', 'k9JZlv 2', 'OwmBnn', 'JVW3E2', 'hxLzax']
header_Values = {
    'col-xs-2-4 href':"product",
    'Fd4QmV src':"image_product_1",
    'FTxtVW':"discount",
    'customized-overlay-image src':"image_product_2",
    'DgXDzJ':"data_product", 
    'bPcAVl':"price_before",
    'k9JZlv':"price_product_1",
    'bx++ig 2':"Emoji",
    'k9JZlv 2':"price_product_2",
    'OwmBnn':"sold",
    'JVW3E2':"place", 
    'hxLzax':"Recommended_shops"
}
def data_process():
  
        path_file = './Data_shopee/Data_1_1_1.xlsx';
        find = pd.read_excel(path_file);
        data_all=[];
        df = pd.read_excel(path_file)
        num_rows, num_columns = df.shape
        print(num_columns,num_rows)
        
        
        Data_everthing=[];
        for i in range(num_rows):
            data_process = {
                "product":[],
                "price_product_2":[],
                "price_product_1":[],
                "image_product_1":[],
                "discount":[],
                "image_product_2":[],
                "data_product":[],
                "price_before":[],
                "Emoji":[],
                "sold":[],
                "place":[],
                "Recommended_shops":[]
            }
            data = "Product_"+str(i+1);
            Product = {
                data:{
                }
            }
            for j in range(12):
                data_input = str(find[header[j]][i]);
                data_process[header_Values[header[j]]]=data_input;
                
            Product[data]=data_process;
            data_all.append(Product);
            
            
            
           
            filename = "Data_process.json"
            
            with open(filename, 'w', encoding='utf-8') as file:
                json.dump(data_all, file, indent=2, ensure_ascii=False)
            print(f'ข้อมูลถูกเขียนลงในไฟล์ {filename}');
            test = len(Data_everthing);
            print(test)
data_process()

# %%
import pandas as pd
import json
import os


file = '/shopee.xlsx';
header = ['col-xs-2-4 href', 'Fd4QmV src', 'FTxtVW',
       'customized-overlay-image src', 'DgXDzJ', 'bPcAVl', 'k9JZlv',
       'bx++ig 2', 'k9JZlv 2', 'OwmBnn', 'JVW3E2', 'hxLzax']

def data_process():
  
        path_file = './Data_shopee/Data_1_1_1.xlsx';
        find = pd.read_excel(path_file);
        data_all=[];
        df = pd.read_excel(path_file)
        num_rows, num_columns = df.shape;

       

        
        
       
data_process()

# %%
# Test_file_name;
def changdeta_and_changename_2(k,i,j):
        # ระบุที่อยู่ของไฟล์และโฟลเดอร์ใหม่
   
    new_file_name = 'data_'+str(k)+'_'+str(i)+'_'+str(j)+'.xlsx'
    print(new_file_name);
num1 = 0 
num1=0
for k in range(len(data_link_product())):
        num1+=1;
        Data = get_link(k);
        
        num2=0;
        for i in range(len(Data)):
            num2+=1;
            num3=0;
            for j in range(9):
                data_sum=Data[i]+str(j);
               
                num3+=1;
                changdeta_and_changename_2(num1,num2,num3);
                print(data_sum);
