         'https://shopee.co.th/%E0%B8%A1%E0%B8%B7%E0%B8%AD%E0%B8%96%E0%B8%B7%E0%B8%AD%E0%B9%81%E0%B8%A5%E0%B8%B0%E0%B8%AD%E0%B8%B8%E0%B8%9B%E0%B8%81%E0%B8%A3%E0%B8%93%E0%B9%8C%E0%B9%80%E0%B8%AA%E0%B8%A3%E0%B8%B4%E0%B8%A1-cat.11044951?page=',
         'https://shopee.co.th/%E0%B8%84%E0%B8%AD%E0%B8%A1%E0%B8%9E%E0%B8%B4%E0%B8%A7%E0%B9%80%E0%B8%95%E0%B8%AD%E0%B8%A3%E0%B9%8C%E0%B9%81%E0%B8%A5%E0%B8%B0%E0%B9%81%E0%B8%A5%E0%B9%87%E0%B8%9B%E0%B8%97%E0%B9%87%E0%B8%AD%E0%B8%9B-cat.11044958?page=',
         'https://shopee.co.th/%E0%B8%AD%E0%B8%B2%E0%B8%AB%E0%B8%B2%E0%B8%A3%E0%B9%81%E0%B8%A5%E0%B8%B0%E0%B9%80%E0%B8%84%E0%B8%A3%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%87%E0%B8%94%E0%B8%B7%E0%B9%88%E0%B8%A1-cat.11044943?page=',
         'https://shopee.co.th/%E0%B8%81%E0%B8%B5%E0%B8%AC%E0%B8%B2%E0%B9%81%E0%B8%A5%E0%B8%B0%E0%B8%81%E0%B8%B4%E0%B8%88%E0%B8%81%E0%B8%A3%E0%B8%A3%E0%B8%A1%E0%B8%81%E0%B8%A5%E0%B8%B2%E0%B8%87%E0%B9%81%E0%B8%88%E0%B9%89%E0%B8%87-cat.11044962?page=',
         'https://shopee.co.th/%E0%B9%80%E0%B8%81%E0%B8%A1%E0%B9%81%E0%B8%A5%E0%B8%B0%E0%B8%AD%E0%B8%B8%E0%B8%9B%E0%B8%81%E0%B8%A3%E0%B8%93%E0%B9%8C%E0%B9%80%E0%B8%AA%E0%B8%A3%E0%B8%B4%E0%B8%A1-cat.11044961?page=',
         'https://shopee.co.th/%E0%B9%80%E0%B8%84%E0%B8%A3%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%87%E0%B9%80%E0%B8%82%E0%B8%B5%E0%B8%A2%E0%B8%99-%E0%B8%AB%E0%B8%99%E0%B8%B1%E0%B8%87%E0%B8%AA%E0%B8%B7%E0%B8%AD-%E0%B9%81%E0%B8%A5%E0%B8%B0%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%AD%E0%B8%94%E0%B8%B4%E0%B9%80%E0%B8%A3%E0%B8%81-cat.11044957?page='
         ];
    return url
# Data_Link
def get_link(i):
    url = data_link_product();
    data_link_all=[];
    page = requests.get(url[i])
    data_link_all.append(url[i]);
    soup = b(page.content,'html.parser')
    all_link = soup.find_all('a',class_ = 'grid-cell grid-cell--with-titles');
    for link in all_link:
        href = link['href']
        if href:
            data = "https://shopee.co.th"+href+"?page=";
            data_link_all.append(data);
    print(data_link_all)
    return(data_link_all);
# Find_file_Donwload_after_change_name
def find_files(directory, pattern):
    for root, dirs, files in os.walk(directory):
        for filename in files:
            if fnmatch(filename, pattern):
                status = True  
                yield os.path.join(root, filename)
def status(path):
    # r"C:\Drag_data_in_shopee\Bot\Data_shopee" 
    directory_to_search = path+'\Data_shopee'  # เปลี่ยนเป็นไดเรกทอรีที่คุณต้องการค้นหา
    file_pattern = "shopee.xlsx" 
    status = False
    for file_path in find_files(directory_to_search, file_pattern):
        status = True;
    return status;
# Check_Header
def check_data(path_file):
        header = ['col-xs-2-4 href', 'Fd4QmV src', 'FTxtVW',
       'customized-overlay-image src', 'DgXDzJ', 'bPcAVl', 'k9JZlv',
       'bx++ig 2', 'k9JZlv 2', 'OwmBnn', 'JVW3E2', 'hxLzax']
       
        df = pd.read_excel(path_file)
       
        is_subset = all(item in df.columns for item in header);
        return is_subset;
# Read Excell
header = ['col-xs-2-4 href', 'Fd4QmV src', 'FTxtVW',
       'customized-overlay-image src', 'DgXDzJ', 'bPcAVl', 'k9JZlv',
       'bx++ig 2', 'k9JZlv 2', 'OwmBnn', 'JVW3E2', 'hxLzax']
header_Values = {
    'col-xs-2-4 href':"product",
    'Fd4QmV src':"image_product_1",
    'FTxtVW':"discount",
    'customized-overlay-image src':"image_product_2",
    'DgXDzJ':"data_product", 
    'bPcAVl':"price_before",
    'k9JZlv':"price_product_1",
    'bx++ig 2':"Emoji",
    'k9JZlv 2':"price_product_2",
    'OwmBnn':"sold",
    'JVW3E2':"place", 
    'hxLzax':"Recommended_shops"
}
def data_process(path_file):
        # path_file = './Data_shopee/Data_1_1_1.xlsx';
        find = pd.read_excel(path_file);
        data_all=[];
        df = pd.read_excel(path_file)
        num_rows, num_columns = df.shape
        Data_everthing=[];
        for i in range(num_rows):
            data_process = {
                "product":[],
                "price_product_2":[],
                "price_product_1":[],
                "image_product_1":[],
                "discount":[],
                "image_product_2":[],
                "data_product":[],
                "price_before":[],
                "Emoji":[],
                "sold":[],
                "place":[],
                "Recommended_shops":[]
            }
            data = "Product_"+str(i+1);
            Product = {
                data:{
                }
            }
            for j in range(12):
                data_input = str(find[header[j]][i]);
                data_process[header_Values[header[j]]]=data_input;
            Product[data]=data_process;
            data_all.append(Product);
            filename = "Data_process.json"
            with open(filename, 'w', encoding='utf-8') as file:
                json.dump(data_all, file, indent=2, ensure_ascii=False)
            test = len(Data_everthing);
# def position_x(x):
#     original_screen_size = [1366,768]
#     original_click_position = (x, 200)
#     new_screen_size = pyautogui.size()
#     new_x = int(original_click_position[0] * (new_screen_size[0] / original_screen_size[0]))
#     return new_x;
# def position_y(y):
#     original_screen_size = [1366,768]
#     original_click_position = (100,y)
#     new_screen_size = pyautogui.size()
#     new_y = int(original_click_position[1] * (new_screen_size[1] / original_screen_size[1]))
#     return new_y;]
path_here = os.getcwd();
def Del():
    folder_path = path_here+'/Data_shopee'
    # ลบไฟล์ทั้งหมดในโฟลเดอร์
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        try:
            if os.path.isfile(file_path):
                os.unlink(file_path)
        except Exception as e:
            print(f"ไม่สามารถลบไฟล์ {file_path}: {e}");
Del();
Data = [];
def custom_sleep(seconds):
    time.sleep(seconds)
def Scoll():
    custom_sleep(2);
    for i in range(7):
        pyautogui.scroll(-750);
        custom_sleep(6);
def click(x,y):
    pyautogui.click(x,y);
    custom_sleep(1.5);
def type_and_enter(text):
    controller = keyboard.Controller();
    controller.type(text);
    custom_sleep(2);
    
def main(x):
    controller = keyboard.Controller();
    custom_sleep(3);
    ky.press_and_release('ctrl+t')
    
    # input path
    type_and_enter(x);
    custom_sleep(4);
    controller.press(keyboard.Key.enter);
    controller.release(keyboard.Key.enter);
    # Mouse clicked at (1360, 264) with Button.left
    custom_sleep(2);
    click(1759, 198);
    Scoll();
    ky.press_and_release('ctrl+o')
 
    custom_sleep(4);
    # Mouse clicked at (834, 114) with Button.left
    # Mouse clicked at (755, 179) with Button.left
# Mouse clicked at (1006, 88) with Button.left
    ky.press_and_release('F11')
    custom_sleep(4);
    for i in range(7):
        controller.press(keyboard.Key.tab)
        controller.release(keyboard.Key.tab)
    custom_sleep(4);
    controller.press(keyboard.Key.enter);
    controller.release(keyboard.Key.enter)
    # Mouse clicked at (1118, 17) with Button.left
    custom_sleep(2);
    ky.press_and_release('alt+F4')
    # reface
    custom_sleep(1);
    ky.press_and_release('ctrl+w')
def changdeta_and_changename(k,i,j):
        # ระบุที่อยู่ของไฟล์และโฟลเดอร์ใหม่
    current_directory = r'C:\Users\\naken\Downloads'
    current_file_name = 'shopee.xlsx'
    new_directory = r'C:\Drag_data_in_shopee\Data_shopee'
    new_file_name = 'data_'+str(k)+'_'+str(i)+'_'+str(j)+'.xlsx'

    # สร้างโฟลเดอร์ใหม่ถ้ายังไม่มี
    if not os.path.exists(new_directory):
        os.makedirs(new_directory)

    # สร้างที่อยู่เต็มของไฟล์ปัจจุบันและไฟล์ใหม่
    current_file_path = os.path.join(current_directory, current_file_name)
    new_file_path = os.path.join(new_directory, new_file_name)

    # ย้าย (เปลี่ยนชื่อ) ไฟล์ไปยังโฟลเดอร์ใหม่
    shutil.move(current_file_path, new_file_path);
def check_data(path_file):
       
        header = ['col-xs-2-4 href', 'Fd4QmV src', 'FTxtVW',
       'customized-overlay-image src', 'DgXDzJ', 'bPcAVl', 'k9JZlv',
       'bx++ig 2', 'k9JZlv 2', 'OwmBnn', 'JVW3E2', 'hxLzax']
       
        df = pd.read_excel(path_file)
        is_subset = all(item in df.columns for item in header);
        return is_subset;

def change_name(k,i,j):
    path ='.\Data_shopee\data_'+str(k)+'_'+str(i)+'_'+str(j)+'.xlsx'
    path_file = path_here+'\Data_shopee\shopee.xlsx';
    new_file_name = 'data_'+str(k)+'_'+str(i)+'_'+str(j)+'.xlsx'
    # สร้างเส้นทางสำหรับไฟล์ใหม่
    new_file_path = os.path.join(os.path.dirname(path_file), new_file_name)

    # เปลี่ยนชื่อไฟล์
    shutil.move(path_file, new_file_path)
    return path;
if __name__ == "__main__":
    num1=0
    for k in range(len(data_link_product())):
        num1+=1;
        Data = get_link(k);
        num2=0;
        for i in range(len(Data)):
            num2+=1;
            num3=0;
            for j in range(9):
                data_sum=Data[i]+str(j);
                main(data_sum);
                find_shopee = status(path_here);
                if(find_shopee==True):
                    num3+=1;
                    path = change_name(num1,num2,num3);
                    print(path);
                    if(check_data(path)==True):
                        data_process(path);
                    else:
                        destination_path = path_here+r'\un_process'
                        shutil.move(path, destination_path)
                        continue;
                else:
                    continue;
                print(data_sum);
            custom_sleep(120);
# Out:
# ['https://shopee.co.th/%E0%B8%84%E0%B8%A7%E0%B8%B2%E0%B8%A1%E0%B8%87%E0%B8%B2%E0%B8%A1%E0%B9%81%E0%B8%A5%E0%B8%B0%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B9%83%E0%B8%8A%E0%B9%89%E0%B8%AA%E0%B9%88%E0%B8%A7%E0%B8%99%E0%B8%95%E0%B8%B1%E0%B8%A7-cat.11044959?page=', 'https://shopee.co.th/เครื่องสำอางสำหรับผิวหน้า-cat.11044959.11045208?page=', 'https://shopee.co.th/เครื่องสำอางสำหรับดวงตา-cat.11044959.11045209?page=', 'https://shopee.co.th/ลิป-cat.11044959.11045200?page=', 'https://shopee.co.th/ผลิตภัณฑ์ดูแลผิวหน้า-cat.11044959.11045204?page=', 'https://shopee.co.th/ผลิตภัณฑ์อาบน้ำและดูแลผิวกาย-cat.11044959.11045201?page=', 'https://shopee.co.th/ผลิตภัณฑ์ดูแลผม-cat.11044959.11045206?page=', 'https://shopee.co.th/ผลิตภัณฑ์สำหรับเล็บ-cat.11044959.11045202?page=', 'https://shopee.co.th/ผลิตภัณฑ์สำหรับผู้ชาย-cat.11044959.11045203?page=', 'https://shopee.co.th/อุปกรณ์เสริมความงาม-cat.11044959.11045199?page=', 'https://shopee.co.th/น้ำหอม-cat.11044959.11045207?page=', 'https://shopee.co.th/ของใช้ส่วนตัว-c
# ...

# %%
# change_name
def change_name(k,i,j):
    path='./Data_shopee/data_'+str(k)+'_'+str(i)+'_'+str(j)+'.xlsx'
    path_file = r'C:\Drag_data_in_shopee\Bot\Data_shopee\shopee.xlsx';
    new_file_name = 'data_'+str(k)+'_'+str(i)+'_'+str(j)+'.xlsx'
    # สร้างเส้นทางสำหรับไฟล์ใหม่
    new_file_path = os.path.join(os.path.dirname(path_file), new_file_name)

    # เปลี่ยนชื่อไฟล์
    shutil.move(path_file, new_file_path)
    return path;
test = change_name(1,1,1);
# Out:
# ./Data_shopee/data_1_1_1.xlsx

# %%
import pandas as pd
import json
import os




def data_process(path_file):
        file = '/shopee.xlsx';
        header = ['col-xs-2-4 href', 'Fd4QmV src', 'FTxtVW',
       'customized-overlay-image src', 'DgXDzJ', 'bPcAVl', 'k9JZlv',
       'bx++ig 2', 'k9JZlv 2', 'OwmBnn', 'JVW3E2', 'hxLzax']
        find = pd.read_excel(path_file);
        df = pd.read_excel(path_file)
        status =0;
        con =False
        is_subset = all(item in df.columns for item in header);
        print(is_subset);
       
                
                       

data_process()
# Out:
# True

# %%
path = './Data_shopee/data_1_1_1.xlsx'
destination_path = r"C:\Drag_data_in_shopee\Bot\Un_process"  # เปลี่ยนเป็นเส้นทางจริงที่ต้องการย้ายไฟล์ไป
shutil.move(path, destination_path);
